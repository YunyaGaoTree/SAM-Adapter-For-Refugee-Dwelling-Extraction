# %% [markdown]
# # Classical Semantic Segmentation
# https://github.com/qubvel/segmentation_models.pytorch

# %%
# print working versions
import sys
print("Python version")
print (sys.version)

print("Version info.")
print (sys.version_info)

import torch
print(torch.__version__)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

import os
path = os.getcwd()
print(path)
# Out:
# Python version
# 3.9.16 (main, Mar  8 2023, 14:00:05)
# [GCC 11.2.0]
# Version info.
# sys.version_info(major=3, minor=9, micro=16, releaselevel='final', serial=0)
# 2.0.1
# Using device: cpu
# /home/yunya/anaconda3/envs/sam/SAM_Adapter

# %% [markdown]
# ## Training
#
# FPN_mit  FPN_res34   FPN_mob Unet_res34  Unet_mob  Unet_res101   MAnet_res34   MAnet_mob  MAnet_res101

# %% [markdown]
# ### Without SR

# %%
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size small --model FPN_mit --epoch 50
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size small --model FPN_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size small --model FPN_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size small --model Unet_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size small --model Unet_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size small --model Unet_res101 --epoch 50

# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size large --model FPN_mit --epoch 50
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size large --model FPN_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size large --model FPN_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size large --model Unet_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size large --model Unet_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size large --model Unet_res101 --epoch 50
# Out:
# torch: 2.0.1+cu117, catalyst: 20.12
# device: cuda
# 1/50 * Epoch (train):   0% 0/7 [00:00<?, ?it/s]/home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/catalyst/contrib/nn/optimizers/radam.py:85: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1485.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# 1/50 * Epoch (train): 100% 7/7 [00:04<00:00,  1.69it/s, dice=0.308, iou=0.182, loss=2.133, loss_bce=0.779, loss_dice=0.692, loss_iou=0.818]
# 1/50 * Epoch (valid): 100% 7/7 [00:00<00:00, 10.27it/s, dice=0.003, iou=0.001, loss=2.302, loss_bce=0.382, loss_dice=0.997, loss_iou=0.999]
# [2023-08-22 22:37:06,832]
# 1/50 * Epoch 1 (_base): lr=0.0005 | momentum=0.9000
# ...

# %%
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size small --model FPN_mit --epoch 50
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size small --model FPN_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size small --model FPN_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size small --model Unet_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size small --model Unet_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size small --model Unet_res101 --epoch 50

# !python run_segmentation_models/train_ss.py --data Djibo2019 --size large --model FPN_mit --epoch 50
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size large --model FPN_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size large --model FPN_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size large --model Unet_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size large --model Unet_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size large --model Unet_res101 --epoch 50
# Out:
# torch: 2.0.1+cu117, catalyst: 20.12
# device: cuda
# 1/50 * Epoch (train):   0% 0/7 [00:00<?, ?it/s]/home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/catalyst/contrib/nn/optimizers/radam.py:85: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1485.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# 1/50 * Epoch (train): 100% 7/7 [00:04<00:00,  1.72it/s, dice=0.295, iou=0.173, loss=2.167, loss_bce=0.793, loss_dice=0.705, loss_iou=0.827]
# 1/50 * Epoch (valid): 100% 7/7 [00:00<00:00,  9.99it/s, dice=0.213, iou=0.119, loss=2.033, loss_bce=0.455, loss_dice=0.787, loss_iou=0.881]
# [2023-08-22 23:23:46,644]
# 1/50 * Epoch 1 (_base): lr=0.0005 | momentum=0.9000
# ...

# %%
# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size small --model FPN_mit --epoch 50
# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size small --model FPN_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size small --model FPN_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size small --model Unet_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size small --model Unet_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size small --model Unet_res101 --epoch 50

# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size large --model FPN_mit --epoch 50
# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size large --model FPN_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size large --model FPN_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size large --model Unet_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size large --model Unet_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Kutupalong2018 --size large --model Unet_res101 --epoch 50
# Out:
# torch: 2.0.1+cu117, catalyst: 20.12
# device: cuda
# 1/50 * Epoch (train):   0% 0/52 [00:00<?, ?it/s]/home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/catalyst/contrib/nn/optimizers/radam.py:85: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1485.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# 1/50 * Epoch (train): 100% 52/52 [00:07<00:00,  6.60it/s, dice=0.610, iou=0.439, loss=1.413, loss_bce=0.577, loss_dice=0.390, loss_iou=0.561]
# 1/50 * Epoch (valid): 100% 112/112 [00:02<00:00, 53.44it/s, dice=0.633, iou=0.463, loss=1.271, loss_bce=0.458, loss_dice=0.367, loss_iou=0.537]
# [2023-08-23 00:06:29,255]
# 1/50 * Epoch 1 (_base): lr=0.0005 | momentum=0.9000
# ...

# %%
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size small --model FPN_mit --epoch 50
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size small --model FPN_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size small --model FPN_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size small --model Unet_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size small --model Unet_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size small --model Unet_res101 --epoch 50

# !python run_segmentation_models/train_ss.py --data Minawao2017 --size large --model FPN_mit --epoch 50
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size large --model FPN_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size large --model FPN_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size large --model Unet_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size large --model Unet_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size large --model Unet_res101 --epoch 50
# Out:
# torch: 2.0.1+cu117, catalyst: 20.12
# device: cuda
# 1/50 * Epoch (train):   0% 0/7 [00:00<?, ?it/s]/home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/catalyst/contrib/nn/optimizers/radam.py:85: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1485.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# 1/50 * Epoch (train): 100% 7/7 [00:04<00:00,  1.69it/s, dice=0.146, iou=0.079, loss=2.171, loss_bce=0.494, loss_dice=0.854, loss_iou=0.921]
# 1/50 * Epoch (valid): 100% 7/7 [00:00<00:00, 11.12it/s, dice=0.001, iou=5.483e-04, loss=2.183, loss_bce=0.231, loss_dice=0.999, loss_iou=0.999]
# [2023-08-23 02:54:17,740]
# 1/50 * Epoch 1 (_base): lr=0.0005 | momentum=0.9000
# ...

# %%
# !python run_segmentation_models/train_ss.py --data Nduta2017 --size small --model FPN_mit --epoch 50
# !python run_segmentation_models/train_ss.py --data Nduta2017 --size small --model FPN_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Nduta2017 --size small --model FPN_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Nduta2017 --size small --model Unet_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Nduta2017 --size small --model Unet_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Nduta2017 --size small --model Unet_res101 --epoch 50

# !python run_segmentation_models/train_ss.py --data Nduta2017 --size large --model FPN_mit --epoch 50
# !python run_segmentation_models/train_ss.py --data Nduta2017 --size large --model FPN_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Nduta2017 --size large --model FPN_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Nduta2017 --size large --model Unet_res34 --epoch 50
# !python run_segmentation_models/train_ss.py --data Nduta2017 --size large --model Unet_mob --epoch 50
# !python run_segmentation_models/train_ss.py --data Nduta2017 --size large --model Unet_res101 --epoch 50
# Out:
# torch: 2.0.1+cu117, catalyst: 20.12
# device: cuda
# 1/50 * Epoch (train):   0% 0/28 [00:00<?, ?it/s]/home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/catalyst/contrib/nn/optimizers/radam.py:85: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1485.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# 1/50 * Epoch (train): 100% 28/28 [00:05<00:00,  4.78it/s, dice=0.305, iou=0.180, loss=1.724, loss_bce=0.260, loss_dice=0.695, loss_iou=0.820]
# 1/50 * Epoch (valid): 100% 63/63 [00:01<00:00, 43.77it/s, dice=0.374, iou=0.230, loss=1.521, loss_bce=0.157, loss_dice=0.626, loss_iou=0.770]
# [2023-08-23 03:33:27,318]
# 1/50 * Epoch 1 (_base): lr=0.0005 | momentum=0.9000
# ...

# %% [markdown]
# ### With SR

# %%
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size small --model FPN_mit --epoch 50 --upsample SR --uptype bilinear
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size small --model FPN_mit --epoch 50 --upsample SR --uptype nearest
# !python run_segmentation_models/train_ss.py --data Dagaha2017 --size small --model FPN_mit --epoch 50 --upsample SR --uptype EDSR

# !python run_segmentation_models/train_ss.py --data Djibo2019 --size small --model FPN_mit --epoch 50 --upsample SR --uptype bilinear
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size small --model FPN_mit --epoch 50 --upsample SR --uptype nearest
# !python run_segmentation_models/train_ss.py --data Djibo2019 --size small --model FPN_mit --epoch 50 --upsample SR --uptype EDSR

# !python run_segmentation_models/train_ss.py --data Minawao2017 --size small --model FPN_mit --epoch 50 --upsample SR --uptype bilinear
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size small --model FPN_mit --epoch 50 --upsample SR --uptype nearest
# !python run_segmentation_models/train_ss.py --data Minawao2017 --size small --model FPN_mit --epoch 50 --upsample SR --uptype EDSR
# Out:
# torch: 2.0.1+cu117, catalyst: 20.12
# device: cuda
# 1/50 * Epoch (train):   0% 0/85 [00:00<?, ?it/s]/home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/catalyst/contrib/nn/optimizers/radam.py:85: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1485.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# 1/50 * Epoch (train): 100% 85/85 [00:09<00:00,  9.34it/s, dice=0.734, iou=0.580, loss=0.983, loss_bce=0.371, loss_dice=0.266, loss_iou=0.420]
# 1/50 * Epoch (valid): 100% 7/7 [00:00<00:00, 10.57it/s, dice=8.987e-04, iou=4.496e-04, loss=2.040, loss_bce=0.051, loss_dice=0.999, loss_iou=1.000]
# [2023-08-23 05:26:23,729]
# 1/50 * Epoch 1 (_base): lr=0.0005 | momentum=0.9000
# ...

# %% [markdown]
# ## Inference

# %%
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size small --model FPN_res34
# Out:
# Traceback (most recent call last):
#   File "/home/yunya/anaconda3/envs/sam/SAM_Adapter/run_segmentation_models/inference_ss.py", line 353, in <module>
#     main(data_name, model_name, size, upsample, path_data, path_model, path_out)
#   File "/home/yunya/anaconda3/envs/sam/SAM_Adapter/run_segmentation_models/inference_ss.py", line 306, in main
#     checkpoint = torch.load(path_model)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/torch/serialization.py", line 791, in load
#     with _open_file_like(f, 'rb') as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/torch/serialization.py", line 271, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/torch/serialization.py", line 252, in __init__
# ...

# %%
# rerun some experiments
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size small --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size small --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size small --model FPN_res34
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size small --model FPN_res34
# Out:
# /home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Predicted probability map.
# Get predicted binary mask with a threshold of 0.5
# Save predicted probability map, binary map and shapefile.
# ...

# %%
# rerun some experiments
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size small --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size small --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size small --model FPN_res34
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size small --model FPN_res34
# Out:
# outputs_SS/Dagaha2017/small/1024/FPN_res34
# {'f1': 0.16794502580479595,
#  'iou': 0.09167029820083422,
#  'precision': 0.32887559508572156,
#  'recall': 0.11276505752976632}
# outputs_SS/Djibo2019/small/1024/FPN_res34
# {'f1': 0.12800839877018008,
#  'iou': 0.0683808616908772,
#  'precision': 0.4348515946839018,
#  'recall': 0.07505062330732241}
# outputs_SS/Nduta2017/small/1024/FPN_res34
# {'f1': 0.06157100912660383,
#  'iou': 0.03176335548864333,
#  'precision': 0.9147808832221566,
#  'recall': 0.03185762248846002}
# outputs_SS/Minawao2017/small/1024/FPN_res34
# {'f1': 0.009199530492882151,
#  'iou': 0.004621020857584874,
#  'precision': 0.3554263565891473,
#  'recall': 0.0046600737887365455}

# %% [markdown]
# ### Without SR

# %%
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size small --model FPN_mit 
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size small --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size small --model FPN_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size small --model Unet_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size small --model Unet_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size small --model Unet_res101 

# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size large --model FPN_mit 
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size large --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size large --model FPN_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size large --model Unet_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size large --model Unet_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size large --model Unet_res101
# Out:
# /home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Predicted probability map.
# Get predicted binary mask with a threshold of 0.5
# Save predicted probability map, binary map and shapefile.
# ...

# %%
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size small --model FPN_mit 
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size small --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size small --model FPN_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size small --model Unet_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size small --model Unet_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size small --model Unet_res101

# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size large --model FPN_mit 
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size large --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size large --model FPN_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size large --model Unet_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size large --model Unet_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size large --model Unet_res101
# Out:
# /home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Predicted probability map.
# Get predicted binary mask with a threshold of 0.5
# Save predicted probability map, binary map and shapefile.
# ...

# %%
# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size small --model FPN_mit 
# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size small --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size small --model FPN_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size small --model Unet_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size small --model Unet_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size small --model Unet_res101 

# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size large --model FPN_mit 
# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size large --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size large --model FPN_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size large --model Unet_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size large --model Unet_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Kutupalong2018 --size large --model Unet_res101
# Out:
# /home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Predicted probability map.
# Get predicted binary mask with a threshold of 0.5
# Save predicted probability map, binary map and shapefile.
# ...

# %%
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size small --model FPN_mit 
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size small --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size small --model FPN_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size small --model Unet_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size small --model Unet_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size small --model Unet_res101 

# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size large --model FPN_mit 
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size large --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size large --model FPN_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size large --model Unet_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size large --model Unet_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size large --model Unet_res101
# Out:
# /home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Predicted probability map.
# Get predicted binary mask with a threshold of 0.5
# Save predicted probability map, binary map and shapefile.
# ...

# %%
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size small --model FPN_mit 
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size small --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size small --model FPN_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size small --model Unet_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size small --model Unet_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size small --model Unet_res101 

# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size large --model FPN_mit 
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size large --model FPN_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size large --model FPN_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size large --model Unet_res34 
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size large --model Unet_mob 
# !torchrun run_segmentation_models/inference_ss.py --data Nduta2017 --size large --model Unet_res101
# Out:
# /home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Predicted probability map.
# Get predicted binary mask with a threshold of 0.5
# Save predicted probability map, binary map and shapefile.
# ...

# %% [markdown]
# ### SR

# %%
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size small --model FPN_mit --upsample SR --uptype bilinear
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size small --model FPN_mit --upsample SR --uptype nearest
# !torchrun run_segmentation_models/inference_ss.py --data Dagaha2017 --size small --model FPN_mit --upsample SR --uptype EDSR

# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size small --model FPN_mit --upsample SR --uptype bilinear
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size small --model FPN_mit --upsample SR --uptype nearest
# !torchrun run_segmentation_models/inference_ss.py --data Djibo2019 --size small --model FPN_mit --upsample SR --uptype EDSR

# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size small --model FPN_mit --upsample SR --uptype bilinear
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size small --model FPN_mit --upsample SR --uptype nearest
# !torchrun run_segmentation_models/inference_ss.py --data Minawao2017 --size small --model FPN_mit --upsample SR --uptype EDSR
# Out:
# /home/yunya/anaconda3/envs/sam/lib/python3.11/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Predicted probability map.
# Get predicted binary mask with a threshold of 0.5
# Save predicted probability map, binary map and shapefile.
# ...

# %% [markdown]
# ## Evaluation

# %% [markdown]
# #### Without SR

# %%
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size small --model FPN_mit 
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size small --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size small --model FPN_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size small --model Unet_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size small --model Unet_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size small --model Unet_res101 

# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size large --model FPN_mit 
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size large --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size large --model FPN_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size large --model Unet_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size large --model Unet_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size large --model Unet_res101
# Out:
# outputs_SS/Dagaha2017/small/1024/FPN_mit
# {'f1': 0.4577288165783921,
#  'iou': 0.29678880180001627,
#  'precision': 0.4290926932242663,
#  'recall': 0.49046040307359523}
# outputs_SS/Dagaha2017/small/1024/FPN_res34
# {'f1': 0.15634760357179478,
#  'iou': 0.08480318951375777,
#  'precision': 0.32141194411757157,
#  'recall': 0.10329791771228755}
# outputs_SS/Dagaha2017/small/1024/FPN_mob
# {'f1': 0.40161439604290894,
#  'iou': 0.2512625207888761,
#  'precision': 0.5639399866201354,
#  'recall': 0.3118506841600513}
# outputs_SS/Dagaha2017/small/1024/Unet_res34
# {'f1': 0.24496567842041686,
#  'iou': 0.1395788534778855,
#  'precision': 0.14607105115526622,
#  'recall': 0.758480427155275}
# outputs_SS/Dagaha2017/small/1024/Unet_mob
# {'f1': 0.2741447382461532,
#  'iou': 0.15884572960513624,
#  'precision': 0.2651538295135351,
#  'recall': 0.28376678000607936}
# outputs_SS/Dagaha2017/small/1024/Unet_res101
# {'f1': 0.22893345682993416,
#  'iou': 0.12926304644666925,
# ...

# %%
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size small --model FPN_mit 
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size small --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size small --model FPN_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size small --model Unet_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size small --model Unet_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size small --model Unet_res101

# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size large --model FPN_mit 
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size large --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size large --model FPN_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size large --model Unet_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size large --model Unet_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Djibo2019 --size large --model Unet_res101
# Out:
# outputs_SS/Djibo2019/small/1024/FPN_mit
# {'f1': 0.4427369350348738,
#  'iou': 0.2843045243899036,
#  'precision': 0.36473195327791635,
#  'recall': 0.563184922042619}
# outputs_SS/Djibo2019/small/1024/FPN_res34
# {'f1': 0.14738447604161448,
#  'iou': 0.07955481001622283,
#  'precision': 0.3957758000669811,
#  'recall': 0.09055291203352443}
# outputs_SS/Djibo2019/small/1024/FPN_mob
# {'f1': 0.46602321607813946,
#  'iou': 0.30380069696144646,
#  'precision': 0.6099702692431967,
#  'recall': 0.377044402795713}
# outputs_SS/Djibo2019/small/1024/Unet_res34
# {'f1': 0.17898018729803675,
#  'iou': 0.09828568917790764,
#  'precision': 0.10255488139786297,
#  'recall': 0.7024718745446414}
# outputs_SS/Djibo2019/small/1024/Unet_mob
# {'f1': 0.27240157634561196,
#  'iou': 0.15767644414111068,
#  'precision': 0.2697392810121843,
#  'recall': 0.2751169486330451}
# outputs_SS/Djibo2019/small/1024/Unet_res101
# {'f1': 0.16138457857836197,
#  'iou': 0.08777505980754671,
# ...

# %%
# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size small --model FPN_mit 
# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size small --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size small --model FPN_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size small --model Unet_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size small --model Unet_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size small --model Unet_res101 

# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size large --model FPN_mit 
# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size large --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size large --model FPN_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size large --model Unet_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size large --model Unet_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Kutupalong2018 --size large --model Unet_res101
# Out:
# outputs_SS/Kutupalong2018/small/1024/FPN_mit
# {'f1': 0.7924430904324291,
#  'iou': 0.6562361233880334,
#  'precision': 0.8246206468381131,
#  'recall': 0.7626824278351614}
# outputs_SS/Kutupalong2018/small/1024/FPN_res34
# {'f1': 0.7395685496880946,
#  'iou': 0.5867582481420005,
#  'precision': 0.8054068903888855,
#  'recall': 0.6836807647012488}
# outputs_SS/Kutupalong2018/small/1024/FPN_mob
# {'f1': 0.5942901049996953,
#  'iou': 0.42276867162521214,
#  'precision': 0.9092213825540617,
#  'recall': 0.44140023423072183}
# outputs_SS/Kutupalong2018/small/1024/Unet_res34
# {'f1': 0.7549924047015213,
#  'iou': 0.6064152224847734,
#  'precision': 0.6949282039751561,
#  'recall': 0.8264219000120345}
# outputs_SS/Kutupalong2018/small/1024/Unet_mob
# {'f1': 0.7565799421338926,
#  'iou': 0.6084668151117459,
#  'precision': 0.8150548663437325,
#  'recall': 0.7059337532421227}
# outputs_SS/Kutupalong2018/small/1024/Unet_res101
# {'f1': 0.7291686252687116,
#  'iou': 0.5737735448889729,
# ...

# %%
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size small --model FPN_mit 
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size small --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size small --model FPN_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size small --model Unet_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size small --model Unet_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size small --model Unet_res101 

# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size large --model FPN_mit 
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size large --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size large --model FPN_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size large --model Unet_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size large --model Unet_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Minawao2017 --size large --model Unet_res101
# Out:
# outputs_SS/Minawao2017/small/1024/FPN_mit
# {'f1': 0.22799001471047114,
#  'iou': 0.1286618115039684,
#  'precision': 0.42374823938799744,
#  'recall': 0.15594731118316071}
# outputs_SS/Minawao2017/small/1024/FPN_res34
# {'f1': 0.07522237915920135,
#  'iou': 0.03908107531214024,
#  'precision': 0.040003257920657995,
#  'recall': 0.628982914756731}
# outputs_SS/Minawao2017/small/1024/FPN_mob
# {'f1': 0.326180653191048,
#  'iou': 0.19487207733193798,
#  'precision': 0.668135465189475,
#  'recall': 0.21575582636270316}
# outputs_SS/Minawao2017/small/1024/Unet_res34
# {'f1': 0.2519271870051857,
#  'iou': 0.14411710149166027,
#  'precision': 0.1642010008700535,
#  'recall': 0.5409192084480988}
# outputs_SS/Minawao2017/small/1024/Unet_mob
# {'f1': 0.3255957002314164,
#  'iou': 0.1944546489019506,
#  'precision': 0.6214830830028207,
#  'recall': 0.2205785199564992}
# outputs_SS/Minawao2017/small/1024/Unet_res101
# {'f1': 0.09723001378859109,
#  'iou': 0.05109919459166214,
# ...

# %%
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size small --model FPN_mit 
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size small --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size small --model FPN_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size small --model Unet_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size small --model Unet_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size small --model Unet_res101 

# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size large --model FPN_mit 
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size large --model FPN_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size large --model FPN_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size large --model Unet_res34 
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size large --model Unet_mob 
# !torchrun run_segmentation_models/evaluation_ss.py --data Nduta2017 --size large --model Unet_res101
# Out:
# outputs_SS/Nduta2017/small/1024/FPN_mit
# {'f1': 0.6265862357071578,
#  'iou': 0.45622539397643297,
#  'precision': 0.7483207843009154,
#  'recall': 0.5389168775927738}
# outputs_SS/Nduta2017/small/1024/FPN_res34
# {'f1': 0.07006004318585823,
#  'iou': 0.03630166987241935,
#  'precision': 0.9086425638017014,
#  'recall': 0.03643465162456599}
# outputs_SS/Nduta2017/small/1024/FPN_mob
# {'f1': 0.5681177744252761,
#  'iou': 0.39676292105466077,
#  'precision': 0.846807209175314,
#  'recall': 0.42744350206686754}
# outputs_SS/Nduta2017/small/1024/Unet_res34
# {'f1': 0.42327445074387715,
#  'iou': 0.26845157100649003,
#  'precision': 0.7205790839597491,
#  'recall': 0.2996439680034346}
# outputs_SS/Nduta2017/small/1024/Unet_mob
# {'f1': 0.5754725760435154,
#  'iou': 0.4039743751967913,
#  'precision': 0.6694883596629574,
#  'recall': 0.5046104783532105}
# outputs_SS/Nduta2017/small/1024/Unet_res101
# {'f1': 0.17133634923597665,
#  'iou': 0.09369484058175029,
# ...

# %% [markdown]
# #### With SR

# %%
# !python run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size small --model FPN_mit --upsample SR --uptype bilinear
# !python run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size small --model FPN_mit --upsample SR --uptype nearest
# !python run_segmentation_models/evaluation_ss.py --data Dagaha2017 --size small --model FPN_mit --upsample SR --uptype EDSR

# !python run_segmentation_models/evaluation_ss.py --data Djibo2019 --size small --model FPN_mit --upsample SR --uptype bilinear
# !python run_segmentation_models/evaluation_ss.py --data Djibo2019 --size small --model FPN_mit --upsample SR --uptype nearest
# !python run_segmentation_models/evaluation_ss.py --data Djibo2019 --size small --model FPN_mit --upsample SR --uptype EDSR

# !python run_segmentation_models/evaluation_ss.py --data Minawao2017 --size small --model FPN_mit --upsample SR --uptype bilinear
# !python run_segmentation_models/evaluation_ss.py --data Minawao2017 --size small --model FPN_mit --upsample SR --uptype nearest
# !python run_segmentation_models/evaluation_ss.py --data Minawao2017 --size small --model FPN_mit --upsample SR --uptype EDSR
# Out:
# outputs_SS/Dagaha2017/small/SR/bilinear/FPN_mit
# {'f1': 0.48493527560683014,
#  'iou': 0.32007561644012383,
#  'precision': 0.41436349414300433,
#  'recall': 0.5844802763502353}
# outputs_SS/Dagaha2017/small/SR/nearest/FPN_mit
# {'f1': 0.27324323548822127,
#  'iou': 0.15824072104647452,
#  'precision': 0.5451098089154025,
#  'recall': 0.18231563494812542}
# outputs_SS/Dagaha2017/small/SR/EDSR/FPN_mit
# {'f1': 0.49401061679855784,
#  'iou': 0.3280306105135926,
#  'precision': 0.39096366411060585,
#  'recall': 0.6708196960807185}
# outputs_SS/Djibo2019/small/SR/bilinear/FPN_mit
# {'f1': 0.5342267000460695,
#  'iou': 0.36446747942731694,
#  'precision': 0.4669366153175342,
#  'recall': 0.6241765861550908}
# outputs_SS/Djibo2019/small/SR/nearest/FPN_mit
# {'f1': 0.41969231129874346,
#  'iou': 0.26557632687572313,
#  'precision': 0.5034349434539239,
#  'recall': 0.35983624679050746}
# outputs_SS/Djibo2019/small/SR/EDSR/FPN_mit
# {'f1': 0.5224790060190746,
#  'iou': 0.35361866812555065,
# ...
